# %%
# Installing packages required for webscraping
# !pip install requests==2.32.3 bs4==0.0.2

# %%
import requests
from bs4 import BeautifulSoup
import csv
from urllib.parse import urljoin
import time
from random import randint
import re
import os

# %%
base_url = 'https://www.filmweb.pl'
ajax_url_template = 'https://www.filmweb.pl/ajax/ranking/film/{}'

film_links = []

for page_num in range(1, 21):  # 1 to 20 included
    ajax_url = ajax_url_template.format(page_num)
    print(f"Downloading {page_num}: {ajax_url}")
    
    r = requests.get(ajax_url)
    r.raise_for_status()
    
    soup = BeautifulSoup(r.text, 'html.parser')
    
    # Find each element with ranking on this page
    ranking_elements = soup.find_all('div', class_='rankingType__header')
    
    for element in ranking_elements:
        link_tag = element.find('a', href=True)
        if link_tag:
            relative_link = link_tag['href']
            full_link = urljoin(base_url, relative_link)
            film_links.append(full_link)
    
    time.sleep(1)  # Pause to avoid overloading the server

print(f"Found {len(film_links)} links to movies.")
# Out:
# Downloading 1: https://www.filmweb.pl/ajax/ranking/film/1
# Downloading 2: https://www.filmweb.pl/ajax/ranking/film/2
# Downloading 3: https://www.filmweb.pl/ajax/ranking/film/3
# Downloading 4: https://www.filmweb.pl/ajax/ranking/film/4
# Downloading 5: https://www.filmweb.pl/ajax/ranking/film/5
# Downloading 6: https://www.filmweb.pl/ajax/ranking/film/6
# Downloading 7: https://www.filmweb.pl/ajax/ranking/film/7
# Downloading 8: https://www.filmweb.pl/ajax/ranking/film/8
# Downloading 9: https://www.filmweb.pl/ajax/ranking/film/9
# Downloading 10: https://www.filmweb.pl/ajax/ranking/film/10
# Downloading 11: https://www.filmweb.pl/ajax/ranking/film/11
# Downloading 12: https://www.filmweb.pl/ajax/ranking/film/12
# Downloading 13: https://www.filmweb.pl/ajax/ranking/film/13
# Downloading 14: https://www.filmweb.pl/ajax/ranking/film/14
# Downloading 15: https://www.filmweb.pl/ajax/ranking/film/15
# Downloading 16: https://www.filmweb.pl/ajax/ranking/film/16
# Downloading 17: https://www.filmweb.pl/ajax/ranking/film/17
# Downloading 18: https://www.filmweb.pl/ajax/ranking/film/18
# Downloading 19: https://www.filmweb.pl/ajax/ranking/film/19
# Downloading 20: https://www.filmweb.pl/ajax/ranking/film/20
# Found 500 links to movies.

# %%
# Function to extract boxoffice amount
def extract_amount(text):
    match = re.search(r"\$\d[\d\s]*", text)
    return match.group(0) if match else None

# %%
already_parsed_movies = []
print(len(film_links))
# Out:
# 500

# %%
file_path = "filmweb_top500.csv"
if(not os.path.isfile(file_path)):
    with open(file_path, mode='a', newline='', encoding='utf8') as file:
        writer = csv.writer(file)
        writer.writerow(["position", "title", "year", "duration", "rating_value", "rating_count", "critic_rating_value", "critic_count", "directors", "screenwriters", "production_countries", "world_premiere", "polish_premiere", "boxoffice", "boxoffice_usa", "boxoffice_outside_usa", "budget", "genres"])
        print("Created csv with headers")
# Out:
# Created csv with headers

# %%
def scrap_single_movie(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    ranking_div = soup.select('div[data-ranking-category="wolrdRanking"]')[0]
    ranking_position = ranking_div["data-position"]
    print(f"{url} ({ranking_position})")

    # zawsze namniejsza pasuajca klasa
    h2 = soup.find("h2", class_="filmCoverSection__originalTitle")
    if h2 and h2.contents and h2.contents[0].strip():
        title = h2.contents[0].strip()
    else:
        h1 = soup.find("h1", class_="filmCoverSection__title")
        title = h1.text.strip() if h1 else "N/A"

    year = "N/A"

    # At first we're looking for <div class="filmCoverSection__year">
    year_div = soup.find("div", class_="filmCoverSection__year")
    if year_div and year_div.text.strip():
        year = year_div.text.strip()
    else:
        # If we don't find It, then we're looking for <h2 class="filmCoverSection__year">
        year_h2 = soup.find("h2", class_="filmCoverSection__year")
        if year_h2 and year_h2.text.strip():
            year = year_h2.text.strip()

    duration = soup.find("div", class_="filmCoverSection__duration").text.strip() # mozliwa wymagana transformacja (np. na same minuty)

    rating_value = soup.find("span", itemprop="ratingValue").text.strip()

    rating_count = soup.find("span", itemprop="ratingCount").text.strip()

    critic_rating_value = None
    for rating_class in ["filmRating__rateValue isHigh", "filmRating__rateValue isMedium", "filmRating__rateValue isLow"]:
        span = soup.find("span", class_=rating_class)
        if span:
            critic_rating_value = span.text.strip()
            break
        
    if critic_rating_value is None:
        critic_rating_value = "N/A" 

    critic_span = soup.find("span", class_="filmRating__count", attrs={"data-rating-count": True})
    critic_count = critic_span["data-rating-count"] if critic_span else None

    director_info = soup.find("span", {"data-type": "directing-info"})
    if director_info:
        directors = [span.text.strip() for span in director_info.find_all("span", itemprop="name")]
    else:
        directors = []


    screenwriter_info = soup.find("span", {"data-type": "screenwriting-info"})
    if screenwriter_info:
        screenwriters = [span.text.strip() for span in screenwriter_info.find_all("span", itemprop="name")]
    else:
        screenwriters = []

    world_premiere = "N/A"
    blocks = soup.find_all("span", class_="block")

    for block in blocks:
        if block.has_attr("content") and "Światowa" in block.text:
            world_premiere = block["content"]
            break

    production_countries = [
        a.find("span").text.strip()
        for a in soup.find("span", class_="filmInfo__info filmInfo__info--productionCountry").find_all("a")
        if a.find("span")
    ]

    premiere_span = soup.find("span", class_="block premiereCountry")
    polish_premiere = premiere_span["content"] if premiere_span and premiere_span.has_attr("content") else None

    boxoffice = soup.find("span", attrs={"data-i18n": "film:info.gross.label"})

    gross_spans = soup.find_all("span", attrs={"data-i18n": "film:info.gross.label"})


    boxoffice = extract_amount(gross_spans[0].text.strip()) if len(gross_spans) > 0 else None
    boxoffice_usa = extract_amount(gross_spans[1].text.strip()) if len(gross_spans) > 1 else None
    boxoffice_outside_usa = extract_amount(gross_spans[2].text.strip()) if len(gross_spans) > 2 else None
    budget = extract_amount(gross_spans[3].text.strip()) if len(gross_spans) > 3 else None

    genres = [span.text.strip() for span in soup.find_all("span", itemprop="genre")]
    return [ranking_position, title, year, duration, rating_value, rating_count, critic_rating_value, critic_count, directors, screenwriters, production_countries, world_premiere, polish_premiere, boxoffice, boxoffice_usa, boxoffice_outside_usa, budget, genres]

# %%
for url in film_links:
    if url in already_parsed_movies:
        continue

    movie_data = scrap_single_movie(url)
    with open(file_path, mode='a', newline='', encoding='utf8') as file:
        writer = csv.writer(file)
        writer.writerow(movie_data)

    time_to_wait = randint(1,4)
    time.sleep(time_to_wait)
    already_parsed_movies.append(url)
# Out:
# https://www.filmweb.pl/film/Skazani+na+Shawshank-1994-1048 (1)
# https://www.filmweb.pl/film/Zielona+mila-1999-862 (2)
# https://www.filmweb.pl/film/Nietykalni-2011-583390 (3)
# https://www.filmweb.pl/film/Ojciec+chrzestny-1972-1089 (4)
# https://www.filmweb.pl/film/Dwunastu+gniewnych+ludzi-1957-30701 (5)
# https://www.filmweb.pl/film/Forrest+Gump-1994-998 (6)
# https://www.filmweb.pl/film/Lot+nad+kuku%C5%82czym+gniazdem-1975-1019 (7)
# https://www.filmweb.pl/film/Ojciec+chrzestny+II-1974-1090 (8)
# https://www.filmweb.pl/film/W%C5%82adca+Pier%C5%9Bcieni%3A+Powr%C3%B3t+kr%C3%B3la-2003-11841 (9)
# https://www.filmweb.pl/film/Lista+Schindlera-1993-1211 (10)
# https://www.filmweb.pl/film/Pulp+Fiction-1994-1039 (11)
# https://www.filmweb.pl/film/%C5%BBycie+jest+pi%C4%99kne-1997-208 (12)
# https://www.filmweb.pl/film/W%C5%82adca+Pier%C5%9Bcieni%3A+Dwie+wie%C5%BCe-2002-31451 (13)
# https://www.filmweb.pl/film/Siedem-1995-702 (14)
# https://www.filmweb.pl/film/Podziemny+kr%C4%85g-1999-837 (15)
# https://www.filmweb.pl/film/Ch%C5%82opcy+z+ferajny-1990-1033 (16)
# https://www.filmweb.pl/film/Pianista-2002-32225 (17)
# https://www.filmweb.pl/film/Milczenie+owiec-1991-1047 (18)
# https://www.filmweb.pl/film/Pi%C4%99kny+umys%C5%82-2001-31864 (19)
# https://www.filmweb.pl/film/Kr%C3%B3l+Lew-1994-6878 (20)
# https://www.filmweb.pl/film/Django-2012-620541 (21)
# https://www.filmweb.pl/film/Incepcja-2010-500891 (22)
# https://www.filmweb.pl/film/Joker-2019-810167 (23)
# https://www.filmweb.pl/film/Gran+Torino-2008-476580 (24)
# https://www.filmweb.pl/film/Cz%C5%82owiek+z+blizn%C4%85-1983-4833 (25)
# https://www.filmweb.pl/film/Coco-2017-752260 (26)
# https://www.filmweb.pl/film/Wyspa+tajemnic-2010-464256 (27)
# https://www.filmweb.pl/film/Leon+zawodowiec-1994-671 (28)
# https://www.filmweb.pl/film/Wi%C4%99zie%C5%84+nienawi%C5%9Bci-1998-30633 (29)
# https://www.filmweb.pl/film/Gladiator-2000-936 (30)
# https://www.filmweb.pl/film/Green+Book-2018-809630 (31)
# https://www.filmweb.pl/film/Szeregowiec+Ryan-1998-179 (32)
# https://www.filmweb.pl/film/Braveheart+Waleczne+Serce-1995-1052 (33)
# https://www.filmweb.pl/film/Buntownik+z+wyboru-1997-21 (34)
# https://www.filmweb.pl/film/Whiplash-2014-698847 (35)
# https://www.filmweb.pl/film/Czas+Apokalipsy-1979-1092 (36)
# https://www.filmweb.pl/film/Ch%C5%82opiec+w+pasiastej+pi%C5%BCamie-2008-420136 (37)
# https://www.filmweb.pl/film/Zapach+kobiety-1992-1093 (38)
# https://www.filmweb.pl/film/Presti%C5%BC-2006-259945 (39)
# https://www.filmweb.pl/film/Gwiezdne+wojny%3A+Cz%C4%99%C5%9B%C4%87+V+Imperium+kontratakuje-1980-525 (40)
# https://www.filmweb.pl/film/Prze%C5%82%C4%99cz+ocalonych-2016-658802 (41)
# https://www.filmweb.pl/film/Dobry%2C+z%C5%82y+i+brzydki-1966-5103 (42)
# https://www.filmweb.pl/film/Avengers%3A+Wojna+bez+granic-2018-693758 (43)
# https://www.filmweb.pl/film/Gwiezdne+wojny%3A+Cz%C4%99%C5%9B%C4%87+VI+Powr%C3%B3t+Jedi-1983-547 (44)
# https://www.filmweb.pl/film/Dawno+temu+w+Ameryce-1984-1038 (45)
# https://www.filmweb.pl/film/W%C5%82adca+Pier%C5%9Bcieni%3A+Dru%C5%BCyna+Pier%C5%9Bcienia-2001-1065 (46)
# https://www.filmweb.pl/film/S%C5%82u%C5%BC%C4%85ce-2011-567127 (47)
# https://www.filmweb.pl/film/Kasyno-1995-1029 (48)
# https://www.filmweb.pl/film/Gor%C4%85czka-1995-660 (49)
# https://www.filmweb.pl/film/Mroczny+Rycerz-2008-236351 (50)
# https://www.filmweb.pl/film/Parasite-2019-798143 (51)
# https://www.filmweb.pl/film/Amadeusz-1984-1286 (52)
# https://www.filmweb.pl/film/B%C4%99karty+wojny-2009-137747 (53)
# https://www.filmweb.pl/film/Diuna%3A+Cz%C4%99%C5%9B%C4%87+druga-2024-10003481 (54)
# https://www.filmweb.pl/film/W+pogoni+za+szcz%C4%99%C5%9Bciem-2006-240046 (55)
# https://www.filmweb.pl/film/Spirited+Away%3A+W+krainie+Bog%C3%B3w-2001-33288 (56)
# https://www.filmweb.pl/film/Pluton-1986-1068 (57)
# https://www.filmweb.pl/film/Infiltracja-2006-136005 (58)
# https://www.filmweb.pl/film/Pami%C4%99tnik-2004-38887 (59)
# https://www.filmweb.pl/film/Bogowie-2014-694378 (60)
# https://www.filmweb.pl/film/Interstellar-2014-375629 (61)
# https://www.filmweb.pl/film/Przebudzenia-1990-1035 (62)
# https://www.filmweb.pl/film/Psychoza-1960-1321 (63)
# https://www.filmweb.pl/film/M%C3%B3j+przyjaciel+Hachiko-2009-449935 (64)
# https://www.filmweb.pl/film/%C5%81owca+jeleni-1978-1045 (65)
# https://www.filmweb.pl/film/Siedem+dusz-2008-459974 (66)
# https://www.filmweb.pl/film/Miasto+Boga-2002-38377 (67)
# https://www.filmweb.pl/film/Avengers%3A+Koniec+gry-2019-790542 (68)
# https://www.filmweb.pl/film/Przekr%C4%99t-2000-1326 (69)
# https://www.filmweb.pl/film/Rain+Man-1988-1008 (70)
# https://www.filmweb.pl/film/Adwokat+diab%C5%82a-1997-2 (71)
# https://www.filmweb.pl/film/Monty+Python+i+%C5%9Awi%C4%99ty+Graal-1975-1096 (72)
# https://www.filmweb.pl/film/W%C5%9Bciek%C5%82e+psy-1992-11843 (73)
# https://www.filmweb.pl/film/Full+Metal+Jacket-1987-8625 (74)
# https://www.filmweb.pl/film/Spider+Man+Uniwersum-2018-743233 (75)
# https://www.filmweb.pl/film/Cinema+Paradiso-1988-8228 (76)
# https://www.filmweb.pl/film/Zwierzogr%C3%B3d-2016-703836 (77)
# https://www.filmweb.pl/film/Gwiezdne+wojny%3A+Cz%C4%99%C5%9B%C4%87+IV+Nowa+nadzieja-1977-759 (78)
# https://www.filmweb.pl/film/Ojciec+chrzestny+III-1990-1091 (79)
# https://www.filmweb.pl/film/Trzy+billboardy+za+Ebbing%2C+Missouri-2017-767406 (80)
# https://www.filmweb.pl/film/Contratiempo.+Niewidzialny+go%C5%9B%C4%87-2016-754287 (81)
# https://www.filmweb.pl/film/Klaus-2019-743825 (82)
# https://www.filmweb.pl/film/Najlepszy-2017-772700 (83)
# https://www.filmweb.pl/film/Mechaniczna+pomara%C5%84cza-1971-1275 (84)
# https://www.filmweb.pl/film/%C5%BB%C4%85d%C5%82o-1973-12137 (85)
# https://www.filmweb.pl/film/Labirynt-2013-507169 (86)
# https://www.filmweb.pl/film/Ojciec-2020-835469 (87)
# https://www.filmweb.pl/film/Z%C5%82ap+mnie%2C+je%C5%9Bli+potrafisz-2002-32362 (88)
# https://www.filmweb.pl/film/Siedmiu+samuraj%C3%B3w-1954-31369 (89)
# https://www.filmweb.pl/film/Pan+od+muzyki-2004-119514 (90)
# https://www.filmweb.pl/film/Jak+rozp%C4%99ta%C5%82em+drug%C4%85+wojn%C4%99+%C5%9Bwiatow%C4%85-1969-6531 (91)
# https://www.filmweb.pl/film/Jak+wytresowa%C4%87+smoka-2010-331014 (92)
# https://www.filmweb.pl/film/Wr%C3%B3g+u+bram-2001-5421 (93)
# https://www.filmweb.pl/film/Requiem+dla+snu-2000-9136 (94)
# https://www.filmweb.pl/film/Ksi%C4%99%C5%BCniczka+Mononoke-1997-971 (95)
# https://www.filmweb.pl/film/Obcy+8.+pasa%C5%BCer+%22Nostromo%22-1979-980 (96)
# https://www.filmweb.pl/film/Koneser-2013-624525 (97)
# https://www.filmweb.pl/film/Shrek-2001-9509 (98)
# https://www.filmweb.pl/film/Ruchomy+zamek+Hauru-2004-128710 (99)
# https://www.filmweb.pl/film/%C5%BBywot+Briana-1979-1099 (100)
# https://www.filmweb.pl/film/%C5%BBycie+Carlita-1993-1094 (101)
# https://www.filmweb.pl/film/Filadelfia-1993-1222 (102)
# https://www.filmweb.pl/film/Przerwana+lekcja+muzyki-1999-882 (103)
# https://www.filmweb.pl/film/Wszystko+za+%C5%BCycie-2007-297829 (104)
# https://www.filmweb.pl/film/Sz%C3%B3sty+zmys%C5%82-1999-825 (105)
# https://www.filmweb.pl/film/Sami+swoi-1967-1113 (106)
# https://www.filmweb.pl/film/U%C5%9Bpieni-1996-616 (107)
# https://www.filmweb.pl/film/Skrzypek+na+dachu-1971-1301 (108)
# https://www.filmweb.pl/film/Cz%C5%82owiek+w+ogniu-2004-107049 (109)
# https://www.filmweb.pl/film/Oppenheimer-2023-10002817 (110)
# https://www.filmweb.pl/film/Bohemian+Rhapsody-2018-619201 (111)
# https://www.filmweb.pl/film/Ch%C5%82opaki+nie+p%C5%82acz%C4%85-2000-843 (112)
# https://www.filmweb.pl/film/L%C5%9Bnienie-1980-1020 (113)
# https://www.filmweb.pl/film/Stowarzyszenie+Umar%C5%82ych+Poet%C3%B3w-1989-1262 (114)
# https://www.filmweb.pl/film/Dzie%C5%84+%C5%9Bwira-2002-31413 (115)
# https://www.filmweb.pl/film/Taks%C3%B3wkarz-1976-1046 (116)
# https://www.filmweb.pl/film/L%C4%99k+pierwotny-1996-1067 (117)
# https://www.filmweb.pl/film/Gra-1997-62 (118)
# https://www.filmweb.pl/film/Prawo+zemsty-2009-475202 (119)
# https://www.filmweb.pl/film/P%C3%B3%C5%82+%C5%BCartem%2C+p%C3%B3%C5%82+serio-1959-30671 (120)
# https://www.filmweb.pl/film/Sens+%C5%BCycia+wg+Monty+Pythona-1983-1100 (121)
# https://www.filmweb.pl/film/Pogorzelisko-2010-512263 (122)
# https://www.filmweb.pl/film/Przemin%C4%99%C5%82o+z+wiatrem-1939-1314 (123)
# https://www.filmweb.pl/film/Grobowiec+%C5%9Bwietlik%C3%B3w-1988-34655 (124)
# https://www.filmweb.pl/film/Za+kilka+dolar%C3%B3w+wi%C4%99cej-1965-37390 (125)
# https://www.filmweb.pl/film/Pok%C3%B3j-2015-731541 (126)
# https://www.filmweb.pl/film/%C5%9Aciana-1982-8673 (127)
# https://www.filmweb.pl/film/Le+Mans+%2766-2019-705791 (128)
# https://www.filmweb.pl/film/Seksmisja-1983-1163 (129)
# https://www.filmweb.pl/film/Porachunki-1998-747 (130)
# https://www.filmweb.pl/film/Mi%C5%9B-1980-896 (131)
# https://www.filmweb.pl/film/Przes%C5%82uchanie-1982-1200 (132)
# https://www.filmweb.pl/film/Tylko+nie+m%C3%B3w+nikomu-2019-830631 (133)
# https://www.filmweb.pl/film/Top+Gun%3A+Maverick-2022-602101 (134)
# https://www.filmweb.pl/film/Helikopter+w+ogniu-2001-31419 (135)
# https://www.filmweb.pl/film/Trainspotting-1996-989 (136)
# https://www.filmweb.pl/film/Efekt+motyla-2004-40252 (137)
# https://www.filmweb.pl/film/Piraci+z+Karaib%C3%B3w%3A+Kl%C4%85twa+Czarnej+Per%C5%82y-2003-37309 (138)
# https://www.filmweb.pl/film/Katedra-2002-34773 (139)
# https://www.filmweb.pl/film/Spider+Man%3A+Poprzez+multiwersum-2023-842826 (140)
# https://www.filmweb.pl/film/Za+wszelk%C4%85+cen%C4%99-2004-123697 (141)
# https://www.filmweb.pl/film/Piraci+z+Karaib%C3%B3w%3A+Skrzynia+umarlaka-2006-107404 (142)
# https://www.filmweb.pl/film/Mandarynki-2013-694062 (143)
# https://www.filmweb.pl/film/Lektor-2008-439584 (144)
# https://www.filmweb.pl/film/Bez+przebaczenia-1992-1241 (145)
# https://www.filmweb.pl/film/Jak+zosta%C4%87+kr%C3%B3lem-2010-539270 (146)
# https://www.filmweb.pl/film/Blow-2001-4258 (147)
# https://www.filmweb.pl/film/Wy%C5%9Bcig-2013-628262 (148)
# https://www.filmweb.pl/film/Witaj+w+klubie-2013-657859 (149)
# https://www.filmweb.pl/film/Wilk+z+Wall+Street-2013-426597 (150)
# https://www.filmweb.pl/film/Polowanie-2012-640318 (151)
# https://www.filmweb.pl/film/Zaginiona+dziewczyna-2014-695409 (152)
# https://www.filmweb.pl/film/Co+gryzie+Gilberta+Grape%27a-1993-1236 (153)
# https://www.filmweb.pl/film/American+Gangster-2007-130130 (154)
# https://www.filmweb.pl/film/Iluzjonista-2006-203657 (155)
# https://www.filmweb.pl/film/Kiler-1997-529 (156)
# https://www.filmweb.pl/film/Misja-1986-1037 (157)
# https://www.filmweb.pl/film/Grand+Budapest+Hotel-2014-661817 (158)
# https://www.filmweb.pl/film/Harry+Potter+i+Insygnia+%C5%9Amierci%3A+Cz%C4%99%C5%9B%C4%87+II-2011-476021 (159)
# https://www.filmweb.pl/film/Gadaj%C4%85ce+g%C5%82owy-1980-35461 (160)
# https://www.filmweb.pl/film/Ch%C5%82opi-2023-857962 (161)
# https://www.filmweb.pl/film/David+Attenborough%3A+%C5%BBycie+na+naszej+planecie-2020-850417 (162)
# https://www.filmweb.pl/film/Casablanca-1942-905 (163)
# https://www.filmweb.pl/film/%C5%9Awi%C4%99ci+z+Bostonu-1999-10213 (164)
# https://www.filmweb.pl/film/W+g%C5%82owie+si%C4%99+nie+mie%C5%9Bci-2015-682170 (165)
# https://www.filmweb.pl/film/Samsara-2011-335332 (166)
# https://www.filmweb.pl/film/R%C3%B3%C5%BCa-2011-564694 (167)
# https://www.filmweb.pl/film/Sherlock+Holmes-2009-426062 (168)
# https://www.filmweb.pl/film/Kafarnaum-2018-807622 (169)
# https://www.filmweb.pl/film/Symetria-2003-103907 (170)
# https://www.filmweb.pl/film/Kr%C3%B3tki+film+o+zabijaniu-1987-1157 (171)
# https://www.filmweb.pl/film/Oszukana-2008-293878 (172)
# https://www.filmweb.pl/film/Twoje+imi%C4%99-2016-760082 (173)
# https://www.filmweb.pl/film/Edward+No%C5%BCycor%C4%99ki-1990-5355 (174)
# https://www.filmweb.pl/film/Prawo+Bronxu-1993-1031 (175)
# https://www.filmweb.pl/film/Tw%C3%B3j+Vincent-2017-698207 (176)
# https://www.filmweb.pl/film/Mroczny+Rycerz+powstaje-2012-506756 (177)
# https://www.filmweb.pl/film/Rocky-1976-9190 (178)
# https://www.filmweb.pl/film/Wo%C5%82y%C5%84-2016-724694 (179)
# https://www.filmweb.pl/film/Absolwent-1967-1042 (180)
# https://www.filmweb.pl/film/Pewnego+razu+na+Dzikim+Zachodzie-1968-4406 (181)
# https://www.filmweb.pl/film/Poszukiwacze+zaginionej+Arki-1981-1216 (182)
# https://www.filmweb.pl/film/Wojownik-2011-499338 (183)
# https://www.filmweb.pl/film/Piraci+z+Karaib%C3%B3w%3A+Na+kra%C5%84cu+%C5%9Bwiata-2007-121760 (184)
# https://www.filmweb.pl/film/W+imi%C4%99+ojca-1993-1231 (185)
# https://www.filmweb.pl/film/Ciekawy+przypadek+Benjamina+Buttona-2008-123383 (186)
# https://www.filmweb.pl/film/Imi%C4%99+r%C3%B3%C5%BCy-1986-1319 (187)
# https://www.filmweb.pl/film/Ta%C5%84cz%C4%85cy+z+wilkami-1990-1257 (188)
# https://www.filmweb.pl/film/Donnie+Brasco-1997-516 (189)
# https://www.filmweb.pl/film/Indiana+Jones+i+ostatnia+krucjata-1989-1213 (190)
# https://www.filmweb.pl/film/D%C5%82ug-1999-781 (191)
# https://www.filmweb.pl/film/%C5%9Aniadanie+u+Tiffany%27ego-1961-1318 (192)
# https://www.filmweb.pl/film/Sam-2001-32021 (193)
# https://www.filmweb.pl/film/%C5%81owca+android%C3%B3w-1982-734 (194)
# https://www.filmweb.pl/film/Sekrety+morza-2014-622476 (195)
# https://www.filmweb.pl/film/Thor%3A+Ragnarok-2017-707970 (196)
# https://www.filmweb.pl/film/Trener-2005-121936 (197)
# https://www.filmweb.pl/film/Harry+Potter+i+wi%C4%99zie%C5%84+Azkabanu-2004-34282 (198)
# https://www.filmweb.pl/film/Mulan-1998-539 (199)
# https://www.filmweb.pl/film/%C5%BBycie+za+%C5%BCycie-2003-33128 (200)
# https://www.filmweb.pl/film/Czarny+%C5%82ab%C4%99d%C5%BA-2010-526137 (201)
# https://www.filmweb.pl/film/Okno+na+podw%C3%B3rze-1954-1324 (202)
# https://www.filmweb.pl/film/Dziewczyna+z+tatua%C5%BCem-2011-565637 (203)
# https://www.filmweb.pl/film/Donnie+Darko-2001-5158 (204)
# https://www.filmweb.pl/film/Kapitan+Phillips-2013-643366 (205)
# https://www.filmweb.pl/film/Ghost+in+the+Shell-1995-31866 (206)
# https://www.filmweb.pl/film/Na+no%C5%BCe-2019-816979 (207)
# https://www.filmweb.pl/film/Chinatown-1974-1027 (208)
# https://www.filmweb.pl/film/Ip+Man-2008-481898 (209)
# https://www.filmweb.pl/film/2001%3A+Odyseja+kosmiczna-1968-1458 (210)
# https://www.filmweb.pl/film/Vabank-1981-1146 (211)
# https://www.filmweb.pl/film/Przypadek-1981-897 (212)
# https://www.filmweb.pl/film/Persona-1966-31654 (213)
# https://www.filmweb.pl/film/Wielki+Mike.+The+Blind+Side-2009-394398 (214)
# https://www.filmweb.pl/film/Wywiad+z+wampirem-1994-1002 (215)
# https://www.filmweb.pl/film/Jak+wytresowa%C4%87+smoka+2-2014-574322 (216)
# https://www.filmweb.pl/film/Mary+i+Max-2009-479892 (217)
# https://www.filmweb.pl/film/Ziemia+obiecana-1974-1073 (218)
# https://www.filmweb.pl/film/Deszczowa+piosenka-1952-30862 (219)
# https://www.filmweb.pl/film/Psy-1992-1142 (220)
# https://www.filmweb.pl/film/Poci%C4%85g-1959-8718 (221)
# https://www.filmweb.pl/film/Doktor+Strangelove%2C+lub+jak+przesta%C5%82em+si%C4%99+martwi%C4%87+i+pokocha%C5%82em+bomb%C4%99-1964-5185 (222)
# https://www.filmweb.pl/film/Cud+w+celi+nr+7-2019-840545 (223)
# https://www.filmweb.pl/film/Doskona%C5%82y+%C5%9Bwiat-1993-5166 (224)
# https://www.filmweb.pl/film/Imperium+S%C5%82o%C5%84ca-1987-1221 (225)
# https://www.filmweb.pl/film/Bogowie+ulicy-2012-624792 (226)
# https://www.filmweb.pl/film/Ultimatum+Bourne%27a-2007-188513 (227)
# https://www.filmweb.pl/film/Ostatni+samuraj-2003-36447 (228)
# https://www.filmweb.pl/film/Bo%C5%BCe+Cia%C5%82o-2019-808863 (229)
# https://www.filmweb.pl/film/American+Beauty-1999-836 (230)
# https://www.filmweb.pl/film/Uprowadzona-2008-401089 (231)
# https://www.filmweb.pl/film/Wielka+Sz%C3%B3stka-2014-685183 (232)
# https://www.filmweb.pl/film/Rzeka+tajemnic-2003-97112 (233)
# https://www.filmweb.pl/film/K+PAX-2001-31831 (234)
# https://www.filmweb.pl/film/9+kompania-2005-181525 (235)
# https://www.filmweb.pl/film/Rzymskie+wakacje-1953-9308 (236)
# https://www.filmweb.pl/film/Nietykalni-1987-1036 (237)
# https://www.filmweb.pl/film/Podejrzani-1995-8727 (238)
# https://www.filmweb.pl/film/W%C5%9Bciek%C5%82y+Byk-1980-1044 (239)
# https://www.filmweb.pl/film/Nienawistna+%C3%B3semka-2015-714192 (240)
# https://www.filmweb.pl/film/Senna-2010-532261 (241)
# https://www.filmweb.pl/film/Joe+Black-1998-74 (242)
# https://www.filmweb.pl/film/Cudowny+ch%C5%82opak-2017-776387 (243)
# https://www.filmweb.pl/film/Hobbit%3A+Niezwyk%C5%82a+podr%C3%B3%C5%BC-2012-343217 (244)
# https://www.filmweb.pl/film/Nie+ma+mocnych-1974-973 (245)
# https://www.filmweb.pl/film/Hannibal-2001-1502 (246)
# https://www.filmweb.pl/film/A%C5%BC+poleje+si%C4%99+krew-2007-239166 (247)
# https://www.filmweb.pl/film/Obdarowani-2017-756152 (248)
# https://www.filmweb.pl/film/M%C3%B3j+s%C4%85siad+Totoro-1988-34656 (249)
# https://www.filmweb.pl/film/Ray-2004-96506 (250)
# https://www.filmweb.pl/film/Iron+Man-2008-122541 (251)
# https://www.filmweb.pl/film/Ta%C5%84cz%C4%85c+w+ciemno%C5%9Bciach-2000-1417 (252)
# https://www.filmweb.pl/film/Znachor-1981-1175 (253)
# https://www.filmweb.pl/film/Matrix-1999-628 (254)
# https://www.filmweb.pl/film/Terminator+2%3A+Dzie%C5%84+s%C4%85du-1991-992 (255)
# https://www.filmweb.pl/film/Duma+i+uprzedzenie-2005-125487 (256)
# https://www.filmweb.pl/film/Nienawi%C5%9B%C4%87-1995-8106 (257)
# https://www.filmweb.pl/film/Jeniec%3A+Tak+daleko+jak+nogi+ponios%C4%85-2001-93761 (258)
# https://www.filmweb.pl/film/Gwiezdne+wojny%3A+Cz%C4%99%C5%9B%C4%87+III+Zemsta+Sith%C3%B3w-2005-5982 (259)
# https://www.filmweb.pl/film/Epoka+lodowcowa-2002-32014 (260)
# https://www.filmweb.pl/film/Chce+si%C4%99+%C5%BCy%C4%87-2013-648982 (261)
# https://www.filmweb.pl/film/Jojo+Rabbit-2019-817417 (262)
# https://www.filmweb.pl/film/Cz%C5%82owiek+s%C5%82o%C5%84-1980-1087 (263)
# https://www.filmweb.pl/film/Wyznania+gejszy-2005-173500 (264)
# https://www.filmweb.pl/film/Dobrze+si%C4%99+k%C5%82amie+w+mi%C5%82ym+towarzystwie-2016-752725 (265)
# https://www.filmweb.pl/film/Dziecko+Rosemary-1968-1104 (266)
# https://www.filmweb.pl/film/Diuna-2021-469476 (267)
# https://www.filmweb.pl/film/Noc+na+Ziemi-1991-8171 (268)
# https://www.filmweb.pl/film/Jutro+b%C4%99dziemy+szcz%C4%99%C5%9Bliwi-2016-757040 (269)
# https://www.filmweb.pl/film/Zapl%C4%85tani-2010-122832 (270)
# https://www.filmweb.pl/film/Kabaret-1972-1313 (271)
# https://www.filmweb.pl/film/Oldboy-2003-115059 (272)
# https://www.filmweb.pl/film/Do+utraty+si%C5%82-2015-609966 (273)
# https://www.filmweb.pl/film/WALL%C2%B7E-2008-399328 (274)
# https://www.filmweb.pl/film/Czarny+kot%2C+bia%C5%82y+kot-1998-514 (275)
# https://www.filmweb.pl/film/Obcy+decyduj%C4%85ce+starcie-1986-994 (276)
# https://www.filmweb.pl/film/Dyktator-1940-31335 (277)
# https://www.filmweb.pl/film/Motylek-1973-8529 (278)
# https://www.filmweb.pl/film/Sherlock+Holmes%3A+Gra+cieni-2011-556864 (279)
# https://www.filmweb.pl/film/Hair-1979-6001 (280)
# https://www.filmweb.pl/film/To+nie+jest+kraj+dla+starych+ludzi-2007-259289 (281)
# https://www.filmweb.pl/film/Cho%C4%87+goni+nas+czas-2007-372601 (282)
# https://www.filmweb.pl/film/Baraka-1992-104077 (283)
# https://www.filmweb.pl/film/Kwiat+pustyni-2009-495616 (284)
# https://www.filmweb.pl/film/Si%C5%82a+i+honor-2000-30585 (285)
# https://www.filmweb.pl/film/S%C3%B3l+ziemi-2014-709349 (286)
# https://www.filmweb.pl/film/To+wspania%C5%82e+%C5%BCycie-1946-31793 (287)
# https://www.filmweb.pl/film/Hobbit%3A+Pustkowie+Smauga-2013-469867 (288)
# https://www.filmweb.pl/film/To%C5%BCsamo%C5%9B%C4%87+Bourne%27a-2002-31497 (289)
# https://www.filmweb.pl/film/Harry+Potter+i+Czara+Ognia-2005-95746 (290)
# https://www.filmweb.pl/film/Amores+perros-2000-31040 (291)
# https://www.filmweb.pl/film/Pan+%C5%BCycia+i+%C5%9Bmierci-2005-111532 (292)
# https://www.filmweb.pl/film/Wielkie+pi%C4%99kno-2013-658317 (293)
# https://www.filmweb.pl/film/Polowanie+na+Czerwony+Pa%C5%BAdziernik-1990-8774 (294)
# https://www.filmweb.pl/film/Twardowsky+2.0-2016-774850 (295)
# https://www.filmweb.pl/film/Jab%C5%82ka+Adama-2005-4313 (296)
# https://www.filmweb.pl/film/S%C5%82aby+punkt-2007-286244 (297)
# https://www.filmweb.pl/film/Wichry+nami%C4%99tno%C5%9Bci-1994-1229 (298)
# https://www.filmweb.pl/film/%C5%9Acigany-1993-1233 (299)
# https://www.filmweb.pl/film/Obywatel+Kane-1941-31279 (300)
# https://www.filmweb.pl/film/Miasto+gniewu-2004-107996 (301)
# https://www.filmweb.pl/film/Billy+Elliot-2000-1471 (302)
# https://www.filmweb.pl/film/Sztuka+spadania-2004-95825 (303)
# https://www.filmweb.pl/film/Marsjanin-2015-715533 (304)
# https://www.filmweb.pl/film/Amator-1979-3808 (305)
# https://www.filmweb.pl/film/Logan%3A+Wolverine-2017-713552 (306)
# https://www.filmweb.pl/film/Cz%C5%82owiek+ringu-2005-107060 (307)
# https://www.filmweb.pl/film/R%C4%99kopis+znaleziony+w+Saragossie-1964-902 (308)
# https://www.filmweb.pl/film/Jestem+Bogiem-2011-548252 (309)
# https://www.filmweb.pl/film/Cast+Away+poza+%C5%9Bwiatem-2000-1470 (310)
# https://www.filmweb.pl/film/By%C5%82+sobie+pies-2017-756406 (311)
# https://www.filmweb.pl/film/Brudny+Harry-1971-4357 (312)
# https://www.filmweb.pl/film/Podaj+dalej-2000-1507 (313)
# https://www.filmweb.pl/film/Snajper-2014-656040 (314)
# https://www.filmweb.pl/film/Paperman-2012-656831 (315)
# https://www.filmweb.pl/film/Deadpool-2016-514675 (316)
# https://www.filmweb.pl/film/Batman+Pocz%C4%85tek-2005-106376 (317)
# https://www.filmweb.pl/film/Marzyciel-2004-98590 (318)
# https://www.filmweb.pl/film/Upadek-1993-11398 (319)
# https://www.filmweb.pl/film/Tamte+dni%2C+tamte+noce-2017-779394 (320)
# https://www.filmweb.pl/film/21+gram%C3%B3w-2003-97088 (321)
# https://www.filmweb.pl/film/Czerwony+smok-2002-32359 (322)
# https://www.filmweb.pl/film/Okr%C4%99t-1981-1289 (323)
# https://www.filmweb.pl/film/Czas+na+mi%C5%82o%C5%9B%C4%87-2013-644432 (324)
# https://www.filmweb.pl/film/Fighter-2010-420435 (325)
# https://www.filmweb.pl/film/S%C4%99dzia-2014-630714 (326)
# https://www.filmweb.pl/film/Ostatnia+rodzina-2016-735683 (327)
# https://www.filmweb.pl/film/Kr%C3%B3tki+film+o+mi%C5%82o%C5%9Bci-1988-1158 (328)
# https://www.filmweb.pl/film/Sugar+Man-2012-644473 (329)
# https://www.filmweb.pl/film/Misery-1990-1237 (330)
# https://www.filmweb.pl/film/Dogville-2003-33328 (331)
# https://www.filmweb.pl/film/Manchester+by+the+Sea-2016-736182 (332)
# https://www.filmweb.pl/film/Annie+Hall-1977-935 (333)
# https://www.filmweb.pl/film/Z+dystansu-2011-587177 (334)
# https://www.filmweb.pl/film/N%C3%B3%C5%BC+w+wodzie-1961-894 (335)
# https://www.filmweb.pl/film/Niebezpieczne+zwi%C4%85zki-1988-1017 (336)
# https://www.filmweb.pl/film/Du%C5%BCa+ryba-2003-36365 (337)
# https://www.filmweb.pl/film/Mama-2014-709353 (338)
# https://www.filmweb.pl/film/Zimna+wojna-2018-764039 (339)
# https://www.filmweb.pl/film/Cyrk+motyli-2009-542342 (340)
# https://www.filmweb.pl/film/Memento-2000-7656 (341)
# https://www.filmweb.pl/film/A+teraz+co%C5%9B+z+zupe%C5%82nie+innej+beczki-1971-1098 (342)
# https://www.filmweb.pl/film/Czas+zabijania-1996-4794 (343)
# https://www.filmweb.pl/film/Amelia-2001-31416 (344)
# https://www.filmweb.pl/film/Nie+lubi%C4%99+poniedzia%C5%82ku-1971-901 (345)
# https://www.filmweb.pl/film/Plan+doskona%C5%82y-2006-207851 (346)
# https://www.filmweb.pl/film/Fortepian-1993-1058 (347)
# https://www.filmweb.pl/film/Si%C3%B3dma+piecz%C4%99%C4%87-1957-1454 (348)
# https://www.filmweb.pl/film/Wesele-2004-124098 (349)
# https://www.filmweb.pl/film/Bulwar+Zachodz%C4%85cego+S%C5%82o%C5%84ca-1950-31278 (350)
# https://www.filmweb.pl/film/Pi%C4%99kna+i+Bestia-1991-31366 (351)
# https://www.filmweb.pl/film/1917-2019-816980 (352)
# https://www.filmweb.pl/film/Mechanik-2004-107377 (353)
# https://www.filmweb.pl/film/Trzy+kolory%3A+Niebieski-1993-1161 (354)
# https://www.filmweb.pl/film/Stra%C5%BCnicy+Galaktyki%3A+Volume+3-2023-806077 (355)
# https://www.filmweb.pl/film/Tajemnice+Los+Angeles-1997-555 (356)
# https://www.filmweb.pl/film/Hotel+Ruanda-2004-139825 (357)
# https://www.filmweb.pl/film/Thelma+i+Louise-1991-984 (358)
# https://www.filmweb.pl/film/Trzy+kolory%3A+Czerwony-1994-1162 (359)
# https://www.filmweb.pl/film/To+w%C5%82a%C5%9Bnie+mi%C5%82o%C5%9B%C4%87-2003-99390 (360)
# https://www.filmweb.pl/film/Harry+Potter+i+Insygnia+%C5%9Amierci%3A+Cz%C4%99%C5%9B%C4%87+I-2010-396969 (361)
# https://www.filmweb.pl/film/Fargo-1996-1253 (362)
# https://www.filmweb.pl/film/12+ma%C5%82p-1995-1210 (363)
# https://www.filmweb.pl/film/Ocean%27s+Eleven%3A+Ryzykowna+gra-2001-8263 (364)
# https://www.filmweb.pl/film/Underground-1995-990 (365)
# https://www.filmweb.pl/film/Dzikie+historie-2014-689545 (366)
# https://www.filmweb.pl/film/Dziki+robot-2024-10049429 (367)
# https://www.filmweb.pl/film/%C5%BBycie+na+pods%C5%82uchu-2006-293175 (368)
# https://www.filmweb.pl/film/Bez+mojej+zgody-2009-463328 (369)
# https://www.filmweb.pl/film/Gnij%C4%85ca+panna+m%C5%82oda-2005-118497 (370)
# https://www.filmweb.pl/film/Krucjata+Bourne%27a-2004-106415 (371)
# https://www.filmweb.pl/film/Krwawy+diament-2006-200092 (372)
# https://www.filmweb.pl/film/Teoria+wszystkiego-2014-691862 (373)
# https://www.filmweb.pl/film/Szklana+pu%C5%82apka-1988-1270 (374)
# https://www.filmweb.pl/film/Harry+Potter+i+Kamie%C5%84+Filozoficzny-2001-30571 (375)
# https://www.filmweb.pl/film/Mustang+z+Dzikiej+Doliny-2002-32363 (376)
# https://www.filmweb.pl/film/Jestem+legend%C4%85-2007-217801 (377)
# https://www.filmweb.pl/film/300-2006-163597 (378)
# https://www.filmweb.pl/film/Spotlight-2015-723550 (379)
# https://www.filmweb.pl/film/Kot+w+butach%3A+Ostatnie+%C5%BCyczenie-2022-714479 (380)
# https://www.filmweb.pl/film/Harry+Potter+i+Ksi%C4%85%C5%BC%C4%99+P%C3%B3%C5%82krwi-2009-142402 (381)
# https://www.filmweb.pl/film/Co+w+duszy+gra-2020-836650 (382)
# https://www.filmweb.pl/film/Kraina+lodu-2013-651932 (383)
# https://www.filmweb.pl/film/Dzie%C5%84+pr%C3%B3by-2001-31686 (384)
# https://www.filmweb.pl/film/Lion.+Droga+do+domu-2016-731226 (385)
# https://www.filmweb.pl/film/August+Rush-2007-224726 (386)
# https://www.filmweb.pl/film/Blade+Runner+2049-2017-630798 (387)
# https://www.filmweb.pl/film/Odlot-2009-436704 (388)
# https://www.filmweb.pl/film/Blues+Brothers-1980-1225 (389)
# https://www.filmweb.pl/film/Stalker-1979-30808 (390)
# https://www.filmweb.pl/film/Deadpool+2-2018-760429 (391)
# https://www.filmweb.pl/film/Ostatni+Mohikanin-1992-8427 (392)
# https://www.filmweb.pl/film/Urodzeni+mordercy-1994-1049 (393)
# https://www.filmweb.pl/film/Mulholland+Drive-2001-30630 (394)
# https://www.filmweb.pl/film/Ma%C5%82y+Ksi%C4%85%C5%BC%C4%99-2015-602026 (395)
# https://www.filmweb.pl/film/Spider+Man%3A+Bez+drogi+do+domu-2021-850261 (396)
# https://www.filmweb.pl/film/Id%C5%BA+i+patrz-1985-35185 (397)
# https://www.filmweb.pl/film/Za+gar%C5%9B%C4%87+dolar%C3%B3w-1964-11889 (398)
# https://www.filmweb.pl/film/Stra%C5%BCnicy+Galaktyki+vol.+2-2017-722146 (399)
# https://www.filmweb.pl/film/Zab%C3%B3jcza+bro%C5%84-1987-1308 (400)
# https://www.filmweb.pl/film/Persepolis-2007-338362 (401)
# https://www.filmweb.pl/film/Prze%C5%82amuj%C4%85c+fale-1996-158 (402)
# https://www.filmweb.pl/film/Popi%C3%B3%C5%82+i+diament-1958-1118 (403)
# https://www.filmweb.pl/film/Hooligans-2005-124119 (404)
# https://www.filmweb.pl/film/Morderstwo+pierwszego+stopnia-1995-1055 (405)
# https://www.filmweb.pl/film/Twardowsky-2015-759564 (406)
# https://www.filmweb.pl/film/Poszukiwany%2C+poszukiwana-1972-1169 (407)
# https://www.filmweb.pl/film/Madagaskar-2005-107535 (408)
# https://www.filmweb.pl/film/Sweeney+Todd%3A+Demoniczny+golibroda+z+Fleet+Street-2007-191945 (409)
# https://www.filmweb.pl/film/Miasteczko+Halloween-1993-7705 (410)
# https://www.filmweb.pl/film/Charlie-2012-572639 (411)
# https://www.filmweb.pl/film/Patriota-2000-944 (412)
# https://www.filmweb.pl/film/Pora+umiera%C4%87-2007-338318 (413)
# https://www.filmweb.pl/film/Mi%C4%99dzy+piek%C5%82em+a+niebem-1998-538 (414)
# https://www.filmweb.pl/film/Lokator-1976-7194 (415)
# https://www.filmweb.pl/film/Tam%2C+gdzie+rosn%C4%85+poziomki-1957-31670 (416)
# https://www.filmweb.pl/film/Zakochany+kundel-1955-93644 (417)
# https://www.filmweb.pl/film/The+Maker-2011-643872 (418)
# https://www.filmweb.pl/film/Powr%C3%B3t-2003-107697 (419)
# https://www.filmweb.pl/film/Millennium%3A+M%C4%99%C5%BCczy%C5%BAni%2C+kt%C3%B3rzy+nienawidz%C4%85+kobiet-2009-465857 (420)
# https://www.filmweb.pl/film/Potwory+i+sp%C3%B3%C5%82ka-2001-31508 (421)
# https://www.filmweb.pl/film/1900%3A+Cz%C5%82owiek+legenda-1998-863 (422)
# https://www.filmweb.pl/film/Zab%C3%B3jczy+numer-2006-130508 (423)
# https://www.filmweb.pl/film/Herkules-1997-522 (424)
# https://www.filmweb.pl/film/Kana%C5%82-1956-1117 (425)
# https://www.filmweb.pl/film/Kolor+purpury-1985-1218 (426)
# https://www.filmweb.pl/film/Wej%C5%9Bcie+smoka-1973-11580 (427)
# https://www.filmweb.pl/film/Casino+Royale-2006-107642 (428)
# https://www.filmweb.pl/film/Indiana+Jones+i+%C5%9Awi%C4%85tynia+Zag%C5%82ady-1984-1214 (429)
# https://www.filmweb.pl/film/Vabank+II%2C+czyli+riposta-1984-1147 (430)
# https://www.filmweb.pl/film/Wr%C3%B3g+publiczny-1998-11783 (431)
# https://www.filmweb.pl/film/%C5%9Awiadek+oskar%C5%BCenia-1957-31581 (432)
# https://www.filmweb.pl/film/Cienka+czerwona+linia-1998-28 (433)
# https://www.filmweb.pl/film/Prawdziwa+historia-2005-124079 (434)
# https://www.filmweb.pl/film/Las+Vegas+Parano-1998-772 (435)
# https://www.filmweb.pl/film/Metropolis-1927-31352 (436)
# https://www.filmweb.pl/film/Powr%C3%B3t+do+przysz%C5%82o%C5%9Bci-1985-8823 (437)
# https://www.filmweb.pl/film/Zabi%C4%87+drozda-1962-11900 (438)
# https://www.filmweb.pl/film/D%C5%BCentelmeni-2019-817420 (439)
# https://www.filmweb.pl/film/Wyspa+ps%C3%B3w-2018-756278 (440)
# https://www.filmweb.pl/film/Avengers-2012-371515 (441)
# https://www.filmweb.pl/film/Tato-1995-1192 (442)
# https://www.filmweb.pl/film/Powr%C3%B3t+do+przysz%C5%82o%C5%9Bci+II-1989-8824 (443)
# https://www.filmweb.pl/film/Wszystko+o+mojej+matce-1999-758 (444)
# https://www.filmweb.pl/film/Z%C5%82o-2003-109907 (445)
# https://www.filmweb.pl/film/Zniewolony.+12+Years+a+Slave-2013-632419 (446)
# https://www.filmweb.pl/film/Dracula-1992-1013 (447)
# https://www.filmweb.pl/film/Planeta+skarb%C3%B3w-2002-32254 (448)
# https://www.filmweb.pl/film/12+prac+Asteriksa-1976-32495 (449)
# https://www.filmweb.pl/film/Rejs-1970-751 (450)
# https://www.filmweb.pl/film/Trzy+kolory%3A+Bia%C5%82y-1994-1160 (451)
# https://www.filmweb.pl/film/Harry+Potter+i+Zakon+Feniksa-2007-113008 (452)
# https://www.filmweb.pl/film/Upi%C3%B3r+w+operze-2004-106461 (453)
# https://www.filmweb.pl/film/Shrek+2-2004-33404 (454)
# https://www.filmweb.pl/film/Stra%C5%BCnicy+Galaktyki-2014-594357 (455)
# https://www.filmweb.pl/film/Byli%C5%9Bmy+%C5%BCo%C5%82nierzami-2002-31750 (456)
# https://www.filmweb.pl/film/Szybcy+i+w%C5%9Bciekli-2001-30588 (457)
# https://www.filmweb.pl/film/Egzorcysta-1973-1315 (458)
# https://www.filmweb.pl/film/Przed+wschodem+s%C5%82o%C5%84ca-1995-4095 (459)
# https://www.filmweb.pl/film/Vincent-1982-11463 (460)
# https://www.filmweb.pl/film/Erin+Brockovich-2000-883 (461)
# https://www.filmweb.pl/film/Porozmawiaj+z+ni%C4%85-2002-32413 (462)
# https://www.filmweb.pl/film/Pokuta-2007-305474 (463)
# https://www.filmweb.pl/film/Plac+Zbawiciela-2006-245950 (464)
# https://www.filmweb.pl/film/Szko%C5%82a+uczu%C4%87-2002-33295 (465)
# https://www.filmweb.pl/film/Sound+of+Metal-2019-763276 (466)
# https://www.filmweb.pl/film/Ukryte+dzia%C5%82ania-2016-763134 (467)
# https://www.filmweb.pl/film/Truman+Show-1998-189 (468)
# https://www.filmweb.pl/film/Dirty+Dancing-1987-11726 (469)
# https://www.filmweb.pl/film/Control-2007-211364 (470)
# https://www.filmweb.pl/film/Jeden+dzie%C5%84-2011-571418 (471)
# https://www.filmweb.pl/film/Miasto+anio%C5%82%C3%B3w-1998-116 (472)
# https://www.filmweb.pl/film/Co%C5%9B-1982-4713 (473)
# https://www.filmweb.pl/film/Prosta+historia-1999-821 (474)
# https://www.filmweb.pl/film/Skazany+na+bluesa-2005-99027 (475)
# https://www.filmweb.pl/film/V+jak+Vendetta-2005-180040 (476)
# https://www.filmweb.pl/film/Who+Am+I.+Mo%C5%BCesz+by%C4%87+kim+chcesz-2014-726430 (477)
# https://www.filmweb.pl/film/Skazaniec-2008-464212 (478)
# https://www.filmweb.pl/film/Anastazja-1997-6 (479)
# https://www.filmweb.pl/film/Lepiej+by%C4%87+nie+mo%C5%BCe-1997-97 (480)
# https://www.filmweb.pl/film/Siedmiu+wspania%C5%82ych-1960-9525 (481)
# https://www.filmweb.pl/film/Pasja-2004-38233 (482)
# https://www.filmweb.pl/film/Spragnieni+mi%C5%82o%C5%9Bci-2000-1508 (483)
# https://www.filmweb.pl/film/Vaiana%3A+Skarb+oceanu-2016-704635 (484)
# https://www.filmweb.pl/film/Co+si%C4%99+wydarzy%C5%82o+w+Madison+County-1995-641 (485)
# https://www.filmweb.pl/film/Zanim+si%C4%99+pojawi%C5%82e%C5%9B-2016-723705 (486)
# https://www.filmweb.pl/film/Przesilenie+zimowe-2023-10032689 (487)
# https://www.filmweb.pl/film/Czekolada-2000-4545 (488)
# https://www.filmweb.pl/film/Pocahontas-1995-8712 (489)
# https://www.filmweb.pl/film/Obiecuj%C4%85ca.+M%C5%82oda.+Kobieta.-2020-835486 (490)
# https://www.filmweb.pl/film/Mi%C5%82o%C5%9B%C4%87-2012-610244 (491)
# https://www.filmweb.pl/film/Captain+Fantastic-2016-720204 (492)
# https://www.filmweb.pl/film/Ucieczka+z+Alcatraz-1979-11306 (493)
# https://www.filmweb.pl/film/Toy+Story-1995-711 (494)
# https://www.filmweb.pl/film/Kill+Bill+2-2004-105575 (495)
# https://www.filmweb.pl/film/Bracia-2009-459973 (496)
# https://www.filmweb.pl/film/Kolekcjoner+ko%C5%9Bci-1999-849 (497)
# https://www.filmweb.pl/film/Motyl+i+skafander-2007-122242 (498)
# https://www.filmweb.pl/film/Sin+City+Miasto+grzechu-2005-112584 (499)
# https://www.filmweb.pl/film/Ostatni+kr%C3%B3l+Szkocji-2006-231584 (500)
